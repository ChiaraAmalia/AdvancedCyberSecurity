# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from itertools import combinations
import numpy as np

# %%
df_14 = pd.read_csv("dataset/Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv")

# %%
test = df_14['Fwd Byts/b Avg'].unique()
test_2 = df_14['Fwd Pkts/b Avg'].unique()
test_3 = df_14['Fwd Blk Rate Avg'].unique()
test_4 = df_14['Bwd Byts/b Avg'].unique()
test_5 = df_14['Bwd Pkts/b Avg'].unique()
test_6 = df_14['Bwd Blk Rate Avg'].unique()

# %%
print(test)
print(test_2)
print(test_3)
print(test_4)
print(test_5)
print(test_6)
# Out:
# [0]
# [0]
# [0]
# [0]
# [0]
# [0]

# %%
test_7 = df_14['Fwd PSH Flags'].unique()
print(test_7)
# Out:
# [0 1]

# %%
df_14[df_14['Label'] == 'Benign']['Fwd PSH Flags'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['Fwd PSH Flags'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['Fwd PSH Flags'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('Fwd PSH Flags')
# Out:
# Text(0.5, 1.0, 'Fwd PSH Flags')

# %%
df_14[df_14['Label'] == 'Benign']['Bwd PSH Flags'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['Bwd PSH Flags'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['Bwd PSH Flags'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('Bwd PSH Flags')
# Out:
# Text(0.5, 1.0, 'Bwd PSH Flags')

# %%
df_14[df_14['Label'] == 'Benign']['Fwd URG Flags'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['Fwd URG Flags'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['Fwd URG Flags'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('Fwd URG Flags')
# Out:
# Text(0.5, 1.0, 'Fwd URG Flags')

# %%
df_14[df_14['Label'] == 'Benign']['Bwd URG Flags'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['Bwd URG Flags'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['Bwd URG Flags'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('Bwd URG Flags')
# Out:
# Text(0.5, 1.0, 'Bwd URG Flags')

# %%
df_14[df_14['Label'] == 'Benign']['FIN Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['FIN Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['FIN Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('FIN Flag Cnt')
# Out:
# Text(0.5, 1.0, 'FIN Flag Cnt')

# %%
df_14[df_14['Label'] == 'Benign']['SYN Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['SYN Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['SYN Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('SYN Flag Cnt')
# Out:
# Text(0.5, 1.0, 'SYN Flag Cnt')

# %%
df_14[df_14['Label'] == 'Benign']['RST Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['RST Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['RST Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('RST Flag Cnt')
# Out:
# Text(0.5, 1.0, 'RST Flag Cnt')

# %%
df_14[df_14['Label'] == 'Benign']['PSH Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['PSH Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['PSH Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('PSH Flag Cnt')
# Out:
# Text(0.5, 1.0, 'PSH Flag Cnt')

# %%
df_14[df_14['Label'] == 'Benign']['ACK Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['ACK Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['ACK Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('ACK Flag Cnt')
# Out:
# Text(0.5, 1.0, 'ACK Flag Cnt')

# %%
df_14[df_14['Label'] == 'Benign']['URG Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['URG Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['URG Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('URG Flag Cnt')
# Out:
# Text(0.5, 1.0, 'URG Flag Cnt')

# %%
df_14[df_14['Label'] == 'Benign']['CWE Flag Count'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['CWE Flag Count'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['CWE Flag Count'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('CWE Flag Count')
# Out:
# Text(0.5, 1.0, 'CWE Flag Count')

# %%
test_8 = df_14['CWE Flag Count'].unique()
print(test_8)
# Out:
# [0]

# %%
df_14[df_14['Label'] == 'Benign']['ECE Flag Cnt'].hist(label='Benign')
df_14[df_14['Label'] == 'FTP-BruteForce']['ECE Flag Cnt'].hist(label='FTP-BruteForce')
df_14[df_14['Label'] == 'SSH-Bruteforce']['ECE Flag Cnt'].hist(label='SSH-Bruteforce')
plt.legend()
plt.title('ECE Flag Cnt')
# Out:
# Text(0.5, 1.0, 'ECE Flag Cnt')

# %% [markdown]
# # Voglio plottare l'istogramma per ogni dimensione, per vedere se ce ne sono alcune che discriminano meglio.

# %%
remove = ['Fwd Byts/b Avg','Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg','Fwd PSH Flags','FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'URG Flag Cnt', 'ECE Flag Cnt','Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'CWE Flag Count']

for a in remove:
    df_14.drop(columns=a,axis=1,inplace=True)

# %%
print(df_14.shape)
# Out:
# (1048575, 64)

# %%
first = ['Dst Port', 'Protocol', 'Timestamp']

for a in first:
    df_14.drop(columns=a,axis=1,inplace=True)

print(df_14.shape)
# Out:
# (1048575, 61)

# %%
for a in df_14.head(0):
    if(df_14[a].isna().sum() > 0):
        print(a)
# Out:
# Flow Byts/s

# %%
df_14.drop('Flow Byts/s',axis=1,inplace=True)

# Da capire perchè dà problemi

#Flow Pkts/s

# %%
for a in df_14.head(0):
    try:
        fig, ax = plt.subplots()
        ax.hist((df_14[a][df_14['Label'] == 'Benign']/df_14[a].max()),label='Benign')
        ax.hist((df_14[a][df_14['Label'] == 'FTP-BruteForce']/df_14[a].max()),label='FTP-BruteForce')
        ax.hist((df_14[a][df_14['Label'] == 'SSH-Bruteforce']/df_14[a].max()),label='SSH-Bruteforce')
        plt.legend()
        plt.title(str(a))
    except:
        print(a)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_19248\2417433207.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# Label

# %%
no_lab = df_14.head(0)

no_lab.pop('Label')

comb = list(combinations(no_lab.head(0), 2))

colors = { 'FTP-BruteForce':'orange', 'SSH-Bruteforce':'black','Benign':'red'}

# %%
print(no_lab.shape)
print(df_14.shape)
# Out:
# (0, 59)
# (1048575, 60)

# %%
print(comb[0][1])

plt.scatter(df_14['Bwd Seg Size Avg']/df_14['Bwd Seg Size Avg'].max(),df_14['Bwd Pkt Len Std']/df_14['Bwd Pkt Len Std'].max(),c=df_14['Label'].map(colors),alpha=.1)
handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=k, markersize=8) for k, v in colors.items()]
plt.legend(title='color', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')
# Out:
# Tot Fwd Pkts

# %%
for a in comb:
    plt.scatter(df_14[a[0]]/df_14[a[0]].max(),df_14[a[1]]/df_14[a[1]].max(),c=df_14['Label'].map(colors),alpha=.1)
    handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=k, markersize=8) for k, v in colors.items()]
    plt.legend(title='color', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.title(str(a[0])+' '+str(a[1]))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[89], line 2
#       1 for a in comb:
# ----> 2     plt.scatter(df_14[a[0]]/df_14[a[0]].max(),df_14[a[1]]/df_14[a[1]].max(),c=df_14['Label'].map(colors),alpha=.1)
#       3     handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=k, markersize=8) for k, v in colors.items()]
#       4     plt.legend(title='color', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\__init__.py:1472, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1469 @functools.wraps(func)
#    1470 def inner(ax, *args, data=None, **kwargs):
#    1471     if data is None:
# -> 1472         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1474     bound = new_sig.bind(ax, *args, **kwargs)
#    1475     auto_label = (bound.arguments.get(label_namer)
#    1476                   or bound.kwargs.get(label_namer))
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\axes\_axes.py:4673, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4667         linewidths = [
#    4668             lw if lw is not None else mpl.rcParams['lines.linewidth']
#    4669             for lw in linewidths]
#    4671 offsets = np.ma.column_stack([x, y])
# -> 4673 collection = mcoll.PathCollection(
#    4674     (path,), scales,
#    4675     facecolors=colors,
#    4676     edgecolors=edgecolors,
#    4677     linewidths=linewidths,
#    4678     offsets=offsets,
#    4679     offset_transform=kwargs.pop('transform', self.transData),
#    4680     alpha=alpha,
#    4681 )
#    4682 collection.set_transform(mtransforms.IdentityTransform())
#    4683 if colors is None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:994, in PathCollection.__init__(self, paths, sizes, **kwargs)
#     980 def __init__(self, paths, sizes=None, **kwargs):
#     981     """
#     982     Parameters
#     983     ----------
#    (...)
#     991         Forwarded to `.Collection`.
#     992     """
# --> 994     super().__init__(**kwargs)
#     995     self.set_paths(paths)
#     996     self.set_sizes(sizes)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:201, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     198 self._offset_transform = offset_transform
#     200 self._path_effects = None
# --> 201 self._internal_update(kwargs)
#     202 self._paths = None
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:1199, in Artist._update_props(self, props, errfmt)
#    1196             if not callable(func):
#    1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
# -> 1199             ret.append(func(v))
#    1200 if ret:
#    1201     self.pchanged()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:816, in Collection.set_alpha(self, alpha)
#     804 """
#     805 Set the transparency of the collection.
#     806
#    (...)
#     813     supported.
#     814 """
#     815 artist.Artist._set_alpha_for_array(self, alpha)
# --> 816 self._set_facecolor(self._original_facecolor)
#     817 self._set_edgecolor(self._original_edgecolor)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:733, in Collection._set_facecolor(self, c)
#     730 if c is None:
#     731     c = self._get_default_facecolor()
# --> 733 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     734 self.stale = True
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\colors.py:448, in to_rgba_array(c, alpha)
#     446     result[:, -1] = alpha if alpha is not None else 1.
#     447 elif c.shape[1] == 4:
# --> 448     result = c.copy()
#     449     if alpha is not None:
#     450         result[:, -1] = alpha
#
# MemoryError: Unable to allocate 32.0 MiB for an array with shape (1048575, 4) and data type float64
# Error in callback <function _draw_all_if_interactive at 0x00000196459859D0> (for post_execute):
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# -> 2082         self.draw(*args, **kwargs)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\backends\backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\figure.py:3140, in Figure.draw(self, renderer)
#    3137         # ValueError can occur when resizing a window.
#    3139 self.patch.draw(renderer)
# -> 3140 mimage._draw_list_compositing_images(
#    3141     renderer, self, artists, self.suppressComposite)
#    3143 for sfig in self.subfigs:
#    3144     sfig.draw(renderer)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:972, in _CollectionWithSizes.draw(self, renderer)
#     969 @artist.allow_rasterization
#     970 def draw(self, renderer):
#     971     self.set_sizes(self._sizes, self.figure.dpi)
# --> 972     super().draw(renderer)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:349, in Collection.draw(self, renderer)
#     346     return
#     347 renderer.open_group(self.__class__.__name__, self.get_gid())
# --> 349 self.update_scalarmappable()
#     351 transform, offset_trf, offsets, paths = self._prepare_points()
#     353 gc = renderer.new_gc()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:892, in Collection.update_scalarmappable(self)
#     890     self._facecolors = self._mapped_colors
#     891 else:
# --> 892     self._set_facecolor(self._original_facecolor)
#     893 if self._edge_is_mapped:
#     894     self._edgecolors = self._mapped_colors
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:733, in Collection._set_facecolor(self, c)
#     730 if c is None:
#     731     c = self._get_default_facecolor()
# --> 733 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     734 self.stale = True
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\colors.py:448, in to_rgba_array(c, alpha)
#     446     result[:, -1] = alpha if alpha is not None else 1.
#     447 elif c.shape[1] == 4:
# --> 448     result = c.copy()
#     449     if alpha is not None:
#     450         result[:, -1] = alpha
#
# MemoryError: Unable to allocate 32.0 MiB for an array with shape (1048575, 4) and data type float64
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\figure.py:3140, in Figure.draw(self, renderer)
#    3137         # ValueError can occur when resizing a window.
#    3139 self.patch.draw(renderer)
# -> 3140 mimage._draw_list_compositing_images(
#    3141     renderer, self, artists, self.suppressComposite)
#    3143 for sfig in self.subfigs:
#    3144     sfig.draw(renderer)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:972, in _CollectionWithSizes.draw(self, renderer)
#     969 @artist.allow_rasterization
#     970 def draw(self, renderer):
#     971     self.set_sizes(self._sizes, self.figure.dpi)
# --> 972     super().draw(renderer)
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:349, in Collection.draw(self, renderer)
#     346     return
#     347 renderer.open_group(self.__class__.__name__, self.get_gid())
# --> 349 self.update_scalarmappable()
#     351 transform, offset_trf, offsets, paths = self._prepare_points()
#     353 gc = renderer.new_gc()
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:892, in Collection.update_scalarmappable(self)
#     890     self._facecolors = self._mapped_colors
#     891 else:
# --> 892     self._set_facecolor(self._original_facecolor)
#     893 if self._edge_is_mapped:
#     894     self._edgecolors = self._mapped_colors
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\collections.py:733, in Collection._set_facecolor(self, c)
#     730 if c is None:
#     731     c = self._get_default_facecolor()
# --> 733 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     734 self.stale = True
#
# File c:\Users\pc\anaconda3\envs\tensor\lib\site-packages\matplotlib\colors.py:453, in to_rgba_array(c, alpha)
#     451 if mask is not None:
#     452     result[mask] = 0
# --> 453 if np.any((result < 0) | (result > 1)):
#     454     raise ValueError("RGBA values should be within 0-1 range")
#     455 return result
#
# MemoryError: Unable to allocate 4.00 MiB for an array with shape (1048575, 4) and data type bool
